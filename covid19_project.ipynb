# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !unzip "/content/drive/My Drive/dataset.zip"
# Out:
# Archive:  /content/drive/My Drive/dataset.zip
#   inflating: final dataset/eval/check/auntminnie-d-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
#   inflating: final dataset/eval/check/NORMAL2-IM-1269-0001-0002.jpeg
# replace final dataset/test/covid/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-003-fig4a.png? [y]es, [n]o, [A]ll, [N]one, [r]ename:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-c901005389f0> in <module>()
# ----> 1 get_ipython().system('unzip "/content/drive/My Drive/dataset.zip"')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     100       kwargs.update({'also_return_output': True})
#     101
# --> 102     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     103
#     104     if pip_warn:
#
# ...

# %%
train_dir="/content/final dataset/"
test_dir="/content/final dataset/"

# %%
from tensorflow.keras.layers import Dropout
from tensorflow import keras
from tensorflow.keras.layers import Dense,MaxPooling2D,Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.models import Sequential

# %%
  model=Sequential()
  model.add(Conv2D(
                   filters=32,
                   kernel_size=(3,3),
                   activation="relu",
                   input_shape=(224,224,3)
                   ))
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.25))

  model.add(Conv2D(
                   filters=64,   
                   kernel_size=(3,3),
                   activation="relu"
                
                   ))
  
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.25))

  model.add(Conv2D(
                   filters=128,   
                   kernel_size=(3,3),
                   activation="relu"
                
                   ))
 
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.25))


  model.add(Flatten())
  model.add(Dense(
                  units=64,
                  activation="relu",
                  ))
  model.add(Dense(1,activation="sigmoid"))
  model.compile(optimizer="adam",
                loss="binary_crossentropy",metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# ...

# %%
from keras.preprocessing import image
# Out:
# Using TensorFlow backend.

# %%
train_datagen = image.ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen =image.ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
        "/content/final dataset/train",
        target_size=(224,224),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 220 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'covid': 0, 'normal': 1}

# %%
validation_generator = test_datagen.flow_from_directory(
        "/content/final dataset/test",
        target_size=(224,224),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 61 images belonging to 3 classes.

# %%
validation_generator.class_indices
# Out:
# {'.ipynb_checkpoints': 0, 'covid': 1, 'normal': 2}

# %%
model.fit(
        train_generator,
        steps_per_epoch=5,
        epochs=20,
        validation_data=validation_generator,
        validation_steps=2)
# Out:
# Epoch 1/20
# 5/5 [==============================] - ETA: 0s - loss: 3.7582 - accuracy: 0.4744
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-727c30fc6546> in <module>()
#       4         epochs=20,
#       5         validation_data=validation_generator,
# ----> 6         validation_steps=2)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ...

# %%
model.evaluate(train_generator)
# Out:
# 7/7 [==============================] - 5s 761ms/step - loss: 0.6930 - accuracy: 0.5000
# [0.693026602268219, 0.5]

# %%
model.evaluate(validation_generator)
# Out:
# 2/2 [==============================] - 1s 352ms/step - loss: 0.1143 - accuracy: 0.9508
# [0.11434432864189148, 0.9508196711540222]

# %%
model.save("covidmodel.h5")

# %%
from tensorflow import keras
new_model=keras.models.load_model("covidmodel.h5")

# %%
import numpy as np

# %%
from keras .preprocessing import image
test_image=image.load_img("/content/final dataset/eval/check/1.jpeg",target_size=(224,224))
test_image=image.img_to_array(test_image)
test_image=np.expand_dims(test_image,axis=0)
result=new_model.predict(test_image)

# %%
result[0][0]
# Out:
# 1.0

# %%
# !pip install joblib

# %%
import joblib
joblib.dump(new_model,"covid_model.pkl")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-0bf90f0c84db> in <module>()
#       1 import joblib
# ----> 2 joblib.dump(new_model,"covid_model.pkl")
#
# /usr/local/lib/python3.6/dist-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     478     elif is_filename:
#     479         with open(filename, 'wb') as f:
# --> 480             NumpyPickler(f, protocol=protocol).dump(value)
#     481     else:
#     482         NumpyPickler(filename, protocol=protocol).dump(value)
#
# /usr/lib/python3.6/pickle.py in dump(self, obj)
#     407         if self.proto >= 4:
#     408             self.framer.start_framing()
# --> 409         self.save(obj)
#     410         self.write(STOP)
#     411         self.framer.end_framing()
#
# /usr/local/lib/python3.6/dist-packages/joblib/numpy_pickle.py in save(self, obj)
# ...

# %%
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# ...
